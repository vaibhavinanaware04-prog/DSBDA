# %%
import nltk
import re
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\vaibh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\vaibh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vaibh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\vaibh\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\vaibh\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
text ="Tokenization is the first step in text analytics.The process of breaking down a text paragraph into smallerchunks such as words or sentences is called Tokenization."

# %%
from nltk.tokenize import sent_tokenize
tokenized_text = sent_tokenize(text)
print("Sentence Tokenization:", tokenized_text)
# Out:
# Sentence Tokenization: ['Tokenization is the first step in text analytics.The process of breaking down a text paragraph into smallerchunks such as words or sentences is called Tokenization.']

# %%
from nltk.tokenize import word_tokenize
tokenized_word = word_tokenize(text)
print("Word Tokenization:", tokenized_word)
# Out:
# Word Tokenization: ['Tokenization', 'is', 'the', 'first', 'step', 'in', 'text', 'analytics.The', 'process', 'of', 'breaking', 'down', 'a', 'text', 'paragraph', 'into', 'smallerchunks', 'such', 'as', 'words', 'or', 'sentences', 'is', 'called', 'Tokenization', '.']

# %%
from nltk.corpus import stopwords
stop_words = set(stopwords.words("english"))
print("Stop Words:", stop_words)
# Out:
# Stop Words: {'them', 've', 'itself', 'all', 'by', 'our', "should've", "weren't", 'doesn', 'what', 'some', "hadn't", "shouldn't", "i've", 'to', 'having', 'does', 'its', 'of', 'here', 'because', 'these', 'he', 'won', 'than', 'd', 'with', "he's", 'their', 's', 'she', 'further', "didn't", 'mustn', 'where', 'at', 'any', 'i', "she's", "hasn't", 'into', 'being', 'not', 'above', 'his', 'wouldn', 'you', 'but', 'only', 'yourself', 'don', 'just', 'will', "they'd", "i'm", 'same', 'should', "mightn't", 'very', 'are', 'shan', "we'd", 'aren', "you'll", "aren't", "she'll", 'while', 'such', 'be', 'from', 'then', 'have', 'below', 'until', 'there', 'when', "mustn't", 'own', "doesn't", 'once', 'before', "they've", 'who', 'ourselves', 'about', 'they', 'out', 'most', "don't", 'between', 'that', 'isn', 'yourselves', "needn't", 'or', "couldn't", 'is', 'for', 'few', 'been', 'were', "wouldn't", "haven't", 'ours', 'the', 'too', 'we', 'whom', 'him', 'how', 'why', 'doing', "we've", 'an', 'y', 'her', 'it', 'down', "they're", "i'll", 'herself', 'against', 'which', 'my', "it's", 'if', 'up', 'nor', 're', "it'd", 'as', 'weren', 'and', 'didn', "he'll", 'was', 'off', 'your', 'himself', 'more', 'hadn', 'haven', 'do', "i'd", 'me', 'during', 'm', "wasn't", 'no', "we'll", 'those', 'ain', 'this', "shan't", 'yours', "you've", 'hasn', 'so', 'did', 'both', 'other', "they'll", 'o', 'after', 'has', "she'd", 'again', 'll', 'shouldn', "that'll", "we're", "you're", 'over', 'hers', "isn't", 'am', "it'll", 'mightn', 'myself', 'now', 'a', "he'd", 'had', 'ma', 'couldn', 'on', 'needn', 'in', 'theirs', 'themselves', "won't", 'each', "you'd", 'wasn', 'under', 'through', 't', 'can'}

# %%
text = "How to remove stop words with NLTK library in Python?"
text = re.sub('[^a-zA-Z]', ' ', text)

# %%
tokens = word_tokenize(text.lower())  
print("Tokenized Sentence:", tokens)
# Out:
# Tokenized Sentence: ['how', 'to', 'remove', 'stop', 'words', 'with', 'nltk', 'library', 'in', 'python']

# %%
filtered_text = [w for w in tokens if w not in stop_words]
print("Filtered Sentence:", filtered_text)
# Out:
# Filtered Sentence: ['remove', 'stop', 'words', 'nltk', 'library', 'python']

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()
e_words = ["wait", "waiting", "waited", "waits"]

# %%
print("Stemming Results:")
for w in e_words:
    rootWord = ps.stem(w)
    print(w, "->", rootWord)
# Out:
# Stemming Results:
# wait -> wait
# waiting -> wait
# waited -> wait
# waits -> wait

# %%
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()

# %%
text = "studies studying cries cry"
tokenization = nltk.word_tokenize(text)

# %%
print("Lemmatization Results:")
for w in tokenization:
    print("Lemma for {} is {}".format(w, wordnet_lemmatizer.lemmatize(w)))
# Out:
# Lemmatization Results:
# Lemma for studies is study
# Lemma for studying is studying
# Lemma for cries is cry
# Lemma for cry is cry

# %%
from nltk import pos_tag
from nltk.tokenize import word_tokenize

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\vaibh\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
pos_tags = nltk.pos_tag(filtered_text)
print("\nPOS Tagging:\n", pos_tags)
# Out:
# POS Tagging:
#  [('remove', 'VB'), ('stop', 'NN'), ('words', 'NNS'), ('nltk', 'JJ'), ('library', 'JJ'), ('python', 'NN')]
