# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/vaibh/Downloads/loan_data.csv")
df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# ...

# %%
df["loan_amnt"].mean()
# Out:
# np.float64(9583.157555555556)

# %%
df[["loan_status", "person_inc"]].mean()
# Out:
# loan_amnt         9583.157556
# person_income    80319.053222
# dtype: float64

# %%
df.mean(numeric_only=True)
# Out:
# person_age                       27.764178
# person_income                 80319.053222
# person_emp_exp                    5.410333
# loan_amnt                      9583.157556
# loan_int_rate                    11.006606
# loan_percent_income               0.139725
# cb_person_cred_hist_length        5.867489
# credit_score                    632.608756
# loan_status                       0.222222
# dtype: float64

# %%
df.describe()
# Out:
#          person_age  person_income  person_emp_exp     loan_amnt  \
# count  45000.000000   4.500000e+04    45000.000000  45000.000000
# mean      27.764178   8.031905e+04        5.410333   9583.157556
# std        6.045108   8.042250e+04        6.063532   6314.886691
# min       20.000000   8.000000e+03        0.000000    500.000000
# 25%       24.000000   4.720400e+04        1.000000   5000.000000
# 50%       26.000000   6.704800e+04        4.000000   8000.000000
# 75%       30.000000   9.578925e+04        8.000000  12237.250000
# max      144.000000   7.200766e+06      125.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   45000.000000         45000.000000                45000.000000
# mean       11.006606             0.139725                    5.867489
# std         2.978808             0.087212                    3.879702
# min         5.420000             0.000000                    2.000000
# ...

# %%
df["loan_amnt"].median()
# Out:
# 8000.0

# %%
df[["loan_amnt", "person_income"]].median()
# Out:
# loan_amnt         8000.0
# person_income    67048.0
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# person_age                       26.00
# person_income                 67048.00
# person_emp_exp                    4.00
# loan_amnt                      8000.00
# loan_int_rate                    11.01
# loan_percent_income               0.12
# cb_person_cred_hist_length        4.00
# credit_score                    640.00
# loan_status                       0.00
# dtype: float64

# %%
df.describe()
# Out:
#          person_age  person_income  person_emp_exp     loan_amnt  \
# count  45000.000000   4.500000e+04    45000.000000  45000.000000
# mean      27.764178   8.031905e+04        5.410333   9583.157556
# std        6.045108   8.042250e+04        6.063532   6314.886691
# min       20.000000   8.000000e+03        0.000000    500.000000
# 25%       24.000000   4.720400e+04        1.000000   5000.000000
# 50%       26.000000   6.704800e+04        4.000000   8000.000000
# 75%       30.000000   9.578925e+04        8.000000  12237.250000
# max      144.000000   7.200766e+06      125.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   45000.000000         45000.000000                45000.000000
# mean       11.006606             0.139725                    5.867489
# std         2.978808             0.087212                    3.879702
# min         5.420000             0.000000                    2.000000
# ...

# %%
df["loan_amnt"].mode()
# Out:
# 0    10000.0
# Name: loan_amnt, dtype: float64

# %%
df[["loan_amnt", "person_income"]].mode()
# Out:
#    loan_amnt  person_income
# 0    10000.0         8000.0

# %%
df.mode(numeric_only=True)
# Out:
#    person_age  person_income  person_emp_exp  loan_amnt  loan_int_rate  \
# 0        23.0         8000.0               0    10000.0          11.01
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  loan_status
# 0                 0.08                         4.0           658            0

# %%
df.describe()
# Out:
#          person_age  person_income  person_emp_exp     loan_amnt  \
# count  45000.000000   4.500000e+04    45000.000000  45000.000000
# mean      27.764178   8.031905e+04        5.410333   9583.157556
# std        6.045108   8.042250e+04        6.063532   6314.886691
# min       20.000000   8.000000e+03        0.000000    500.000000
# 25%       24.000000   4.720400e+04        1.000000   5000.000000
# 50%       26.000000   6.704800e+04        4.000000   8000.000000
# 75%       30.000000   9.578925e+04        8.000000  12237.250000
# max      144.000000   7.200766e+06      125.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   45000.000000         45000.000000                45000.000000
# mean       11.006606             0.139725                    5.867489
# std         2.978808             0.087212                    3.879702
# min         5.420000             0.000000                    2.000000
# ...

# %%
mean_value = df["loan_amnt"].mean()
abs_dev = abs(df["loan_amnt"] - mean_value)
abs_dev.head(10)
# Out:
# 0    25416.842444
# 1     8583.157556
# 2     4083.157556
# 3    25416.842444
# 4    25416.842444
# 5     7083.157556
# 6    25416.842444
# 7    25416.842444
# 8    25416.842444
# 9     7983.157556
# Name: loan_amnt, dtype: float64

# %%
df["loan_amnt_abs_dev"] = abs_dev
df.head(10)
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
# 5        21.0        female      High School        12951.0               0
# 6        26.0        female         Bachelor        93471.0               1
# 7        24.0        female      High School        95550.0               5
# 8        24.0        female        Associate       100684.0               3
# 9        21.0        female      High School        12739.0               0
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# ...

# %%
mad_value = abs_dev.mean()
print("Mean Absolute Deviation for loan_amnt:", mad_value)
# Out:
# Mean Absolute Deviation for loan_amnt: 4907.465811693827

# %%
df["loan_amnt"].var()
# Out:
# 39877793.914373636

# %%
df[["loan_amnt", "person_income", "loan_int_rate"]].var()
# Out:
# loan_amnt        3.987779e+07
# person_income    6.467778e+09
# loan_int_rate    8.873299e+00
# dtype: float64

# %%
df.var(numeric_only=True)
# Out:
# person_age                    3.654333e+01
# person_income                 6.467778e+09
# person_emp_exp                3.676642e+01
# loan_amnt                     3.987779e+07
# loan_int_rate                 8.873299e+00
# loan_percent_income           7.605987e-03
# cb_person_cred_hist_length    1.505209e+01
# credit_score                  2.543776e+03
# loan_status                   1.728433e-01
# loan_amnt_abs_dev             1.579404e+07
# dtype: float64

# %%
df["person_income"].var()
df["credit_score"].var()
# Out:
# 2543.77647837307

# %%
df["loan_amnt"].std()
# Out:
# 6314.8866905411405

# %%
df[["loan_amnt", "person_income"]].std()
# Out:
# loan_amnt         6314.886691
# person_income    80422.498632
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# person_age                        6.045108
# person_income                 80422.498632
# person_emp_exp                    6.063532
# loan_amnt                      6314.886691
# loan_int_rate                     2.978808
# loan_percent_income               0.087212
# cb_person_cred_hist_length        3.879702
# credit_score                     50.435865
# loan_status                       0.415744
# loan_amnt_abs_dev              3974.171364
# dtype: float64

# %%
loan_range = df["loan_amnt"].max() - df["loan_amnt"].min()
print("Range of loan_amnt:", loan_range)
# Out:
# Range of loan_amnt: 34500.0

# %%
range_all = df.max(numeric_only=True) - df.min(numeric_only=True)
print(range_all)
# Out:
# person_age                    1.240000e+02
# person_income                 7.192766e+06
# person_emp_exp                1.250000e+02
# loan_amnt                     3.450000e+04
# loan_int_rate                 1.458000e+01
# loan_percent_income           6.600000e-01
# cb_person_cred_hist_length    2.800000e+01
# credit_score                  4.600000e+02
# loan_status                   1.000000e+00
# loan_amnt_abs_dev             2.541468e+04
# dtype: float64

# %%
q1 = df["loan_amnt"].quantile(0.25)
print("Q1 (25%):", q1)
# Out:
# Q1 (25%): 5000.0

# %%
q2 = df["loan_amnt"].quantile(0.50) 
print("Q2 (Median):", q2)
# Out:
# Q2 (Median): 8000.0

# %%
q3 = df["loan_amnt"].quantile(0.75)
print("Q3 (75%):", q3)
# Out:
# Q3 (75%): 12237.25

# %%
df.quantile([0.25, 0.5, 0.75], numeric_only=True)
# Out:
#       person_age  person_income  person_emp_exp  loan_amnt  loan_int_rate  \
# 0.25        24.0       47204.00             1.0    5000.00           8.59
# 0.50        26.0       67048.00             4.0    8000.00          11.01
# 0.75        30.0       95789.25             8.0   12237.25          12.99
#
#       loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0.25                 0.07                         3.0         601.0
# 0.50                 0.12                         4.0         640.0
# 0.75                 0.19                         8.0         670.0
#
#       loan_status  loan_amnt_abs_dev
# 0.25          0.0        2383.157556
# 0.50          0.0        4541.842444
# 0.75          0.0        6583.157556

# %%
skew_value = df["loan_amnt"].skew()
print("Skewness of loan_amnt:", skew_value)
# Out:
# Skewness of loan_amnt: 1.1797312856279225

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["loan_amnt"], kde=True, bins=30, color="blue")
plt.title("Distribution of loan_amnt with Skewness")
plt.xlabel("loan_amnt")
plt.ylabel("Frequency")
plt.show()

# %%
df[["loan_amnt", "person_income"]].skew()
# Out:
# loan_amnt         1.179731
# person_income    34.137583
# dtype: float64

# %%
fig, axes = plt.subplots(1, 2, figsize=(12,5))

sns.histplot(df["loan_amnt"], kde=True, bins=30, color="orange", ax=axes[0])
axes[0].set_title("loan_amnt Distribution")

sns.histplot(df["person_income"], kde=True, bins=30, color="green", ax=axes[1])
axes[1].set_title("person_income Distribution")

plt.show()
