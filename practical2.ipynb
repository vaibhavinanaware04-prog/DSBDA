# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/vaibh/Downloads/DSBDA Prac/StudentsPerformance.csv")

# %%
df
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0           64            NaN           70.0             88.0          2020.0
# 1           68           94.0           62.0             79.0          2020.0
# 2           72           88.0           77.0             90.0          2018.0
# 3           77           80.0           63.0             99.0          2020.0
# 4           80           93.0           60.0             96.0          2020.0
# ..         ...            ...            ...              ...             ...
# 95          61           84.0           69.0             68.0             NaN
# 96          72           75.0           86.0              NaN          2020.0
# 97          95           85.0           80.0             61.0          2021.0
# 98          69           88.0           55.0             99.0             NaN
# 99          67           84.0           62.0             81.0             NaN
#
#     Placement_Offer_Count
# 0                       3
# 1                       2
# 2                       3
# 3                       3
# 4                       3
# ..                    ...
# 95                      1
# 96                      2
# 97                      1
# 98                      3
# 99                      2
#
# [100 rows x 6 columns]

# %%
df.head()
# Out:
#    Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0          64            NaN           70.0             88.0          2020.0
# 1          68           94.0           62.0             79.0          2020.0
# 2          72           88.0           77.0             90.0          2018.0
# 3          77           80.0           63.0             99.0          2020.0
# 4          80           93.0           60.0             96.0          2020.0
#
#    Placement_Offer_Count
# 0                      3
# 1                      2
# 2                      3
# 3                      3
# 4                      3

# %%
df.shape
# Out:
# (100, 6)

# %%
df.columns
# Out:
# Index(['Math_Score', 'Reading_Score', 'Writing_Score', 'Placement_Score',
#        'Club_Join_Date', 'Placement_Offer_Count'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Math_Score                 int64
# Reading_Score            float64
# Writing_Score            float64
# Placement_Score          float64
# Club_Join_Date           float64
# Placement_Offer_Count      int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Math_Score                0
# Reading_Score             9
# Writing_Score             7
# Placement_Score           3
# Club_Join_Date           22
# Placement_Offer_Count     0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(41)

# %%
series = pd.isnull(df["Math_Score"])
df[series]
# Out:
# Empty DataFrame
# Columns: [Math_Score, Reading_Score, Writing_Score, Placement_Score, Club_Join_Date, Placement_Offer_Count]
# Index: []

# %%
df['Math_Score'] = df['Math_Score'].fillna(df['Math_Score'].mean())
df['Reading_Score'] = df['Reading_Score'].fillna(df['Reading_Score'].median())
df['Writing_Score'] = df['Writing_Score'].fillna(df['Writing_Score'].mode())
df['Placement_Score'] = df['Placement_Score'].fillna(df['Placement_Score'].mean())

# %%
df
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0           64           85.0           70.0        88.000000          2020.0
# 1           68           94.0           62.0        79.000000          2020.0
# 2           72           88.0           77.0        90.000000          2018.0
# 3           77           80.0           63.0        99.000000          2020.0
# 4           80           93.0           60.0        96.000000          2020.0
# ..         ...            ...            ...              ...             ...
# 95          61           84.0           69.0        68.000000             NaN
# 96          72           75.0           86.0        87.804124          2020.0
# 97          95           85.0           80.0        61.000000          2021.0
# 98          69           88.0           55.0        99.000000             NaN
# 99          67           84.0           62.0        81.000000             NaN
#
#     Placement_Offer_Count
# 0                       3
# 1                       2
# 2                       3
# 3                       3
# 4                       3
# ..                    ...
# 95                      1
# 96                      2
# 97                      1
# 98                      3
# 99                      2
#
# [100 rows x 6 columns]

# %%
df['Club_Join_Date'] = df['Club_Join_Date'].fillna(df['Club_Join_Date'].mode()[0])
df
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0           64           85.0           70.0        88.000000          2020.0
# 1           68           94.0           62.0        79.000000          2020.0
# 2           72           88.0           77.0        90.000000          2018.0
# 3           77           80.0           63.0        99.000000          2020.0
# 4           80           93.0           60.0        96.000000          2020.0
# ..         ...            ...            ...              ...             ...
# 95          61           84.0           69.0        68.000000          2020.0
# 96          72           75.0           86.0        87.804124          2020.0
# 97          95           85.0           80.0        61.000000          2021.0
# 98          69           88.0           55.0        99.000000          2020.0
# 99          67           84.0           62.0        81.000000          2020.0
#
#     Placement_Offer_Count
# 0                       3
# 1                       2
# 2                       3
# 3                       3
# 4                       3
# ..                    ...
# 95                      1
# 96                      2
# 97                      1
# 98                      3
# 99                      2
#
# [100 rows x 6 columns]

# %%
col = ['Math_Score', 'Reading_Score', 'Writing_Score']
df.boxplot(col)
plt.show()

# %%
col = ['Placement_Score']
df.boxplot(col)
plt.show()

# %%
import numpy as np
from scipy import stats
z = np.abs(stats.zscore(df['Math_Score']))
print(z)
# Out:
# [0.89567475 0.31594999 0.26377476 0.98843071 1.42322428 0.84349952
#  0.26377476 1.04060594 0.75074356 0.31594999 0.26377476 0.1710188
#  1.04060594 0.98843071 0.84349952 1.33046832 1.47539951 0.40870595
#  0.98843071 0.69856833 0.98843071 0.60581237 2.05512426 0.60581237
#  1.04060594 1.18553713 0.84349952 1.18553713 1.27829309 0.26377476
#  0.11884358 1.33046832 1.27829309 0.40870595 0.84349952 1.1333619
#  0.02608761 0.26377476 1.42322428 0.75074356 0.84349952 1.42322428
#  0.75074356 1.18553713 0.40870595 0.11884358 0.1710188  1.18553713
#  0.40870595 1.27829309 0.02608761 1.42322428 0.26377476 0.11884358
#  0.75074356 1.18553713 0.31594999 0.31594999 0.46088118 0.40870595
#  0.69856833 1.33046832 1.47539951 0.02608761 0.69856833 1.1333619
#  1.27829309 1.18553713 0.11884358 0.98843071 0.46088118 0.89567475
#  0.46088118 0.02608761 1.04060594 0.60581237 1.42322428 1.04060594
#  0.26377476 0.84349952 1.27829309 0.69856833 0.02608761 1.47539951
#  0.75074356 1.33046832 0.02608761 0.40870595 1.18553713 2.87253617
#  0.26377476 1.6203307  0.26377476 0.60581237 0.60581237 1.33046832
#  0.26377476 3.59719212 0.1710188  0.46088118]

# %%
np.where
# Out:
# <function where at 0x0000017FC072FCF0>

# %%
threshold = 3
np.where(z > threshold)
# Out:
# (array([97]),)

# %%
sorted_rscore = sorted(df['Reading_Score'])
q1 = np.percentile(sorted_rscore, 25)
q3 = np.percentile(sorted_rscore, 75)
IQR = q3 - q1
lower = q1 - (1.5 * IQR)
upper = q3 + (1.5 * IQR)

print("Lower Bound:", lower)
print("Upper Bound:", upper)
# Out:
# Lower Bound: 65.375
# Upper Bound: 106.375

# %%
outliers = []
for i in sorted_rscore:
    if i < lower or i > upper:
        outliers.append(i)
outliers
# Out:
# [52.0,
#  52.0,
#  53.0,
#  53.0,
#  57.0,
#  58.0,
#  62.0,
#  107.0,
#  108.0,
#  109.0,
#  109.0,
#  110.0,
#  110.0]

# %%
plt.scatter(df['Placement_Score'], df['Placement_Offer_Count'])
plt.xlabel("Placement Score")
plt.ylabel("Placement Offer Count")

plt.show()

# %%
print(np.where((df['Placement_Score'] > 85) & (df['Placement_Offer_Count'] < 3)))
# Out:
# (array([ 9, 15, 27, 36, 45, 61, 66, 83, 85, 87, 92, 96]),)

# %%
Q1 = df['Reading_Score'].quantile(0.25)
Q3 = df['Reading_Score'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

# %%
median = np.median(sorted_rscore)

df['Reading_Score'] = np.where(
    df['Reading_Score'] > upper,
    median,
    df['Reading_Score']
)

df['Reading_Score'] = np.where(
    df['Reading_Score'] < lower,
    median,
    df['Reading_Score']
)
df
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date  \
# 0           64           85.0           70.0        88.000000          2020.0
# 1           68           94.0           62.0        79.000000          2020.0
# 2           72           88.0           77.0        90.000000          2018.0
# 3           77           80.0           63.0        99.000000          2020.0
# 4           80           93.0           60.0        96.000000          2020.0
# ..         ...            ...            ...              ...             ...
# 95          61           84.0           69.0        68.000000          2020.0
# 96          72           75.0           86.0        87.804124          2020.0
# 97          95           85.0           80.0        61.000000          2021.0
# 98          69           88.0           55.0        99.000000          2020.0
# 99          67           84.0           62.0        81.000000          2020.0
#
#     Placement_Offer_Count  log_reading  log_math
# 0                       3     1.929419  1.806180
# 1                       2     1.973128  1.832509
# 2                       3     1.944483  1.857332
# 3                       3     1.903090  1.886491
# 4                       3     1.968483  1.903090
# ..                    ...          ...       ...
# 95                      1     1.924279  1.785330
# 96                      3     1.875061  1.857332
# 97                      1     1.929419  1.977724
# 98                      3     1.944483  1.838849
# 99                      2     1.924279  1.826075
#
# [100 rows x 8 columns]

# %%
df.loc[df['Placement_Score'] < 75, 'Placement_Offer_Count'] = 1

df.loc[
    (df['Placement_Score'] >= 75) & (df['Placement_Score'] <= 85),
    'Placement_Offer_Count'
] = 2

df.loc[df['Placement_Score'] > 85, 'Placement_Offer_Count'] = 3

# %%
df['Reading_Score'].plot(kind='hist')
plt.title("Before Log")
plt.show()

# %%
df['log_reading'] = np.log10(df['Reading_Score'])

df['log_reading'].plot(kind='hist')
plt.title("After Log")
plt.show()

# %%
df.loc[df['Placement_Score'] > 85, 'Placement_Offer_Count'] = 3

# %%
df['log_math'] = np.log10(df['Math_Score'])

df['log_math'].plot(kind='hist')
plt.title("After Log")
plt.show()

# %%
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(df['Placement_Score'], df['Placement_ffer'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'placement_score'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 2
#       1 fig, ax = plt.subplots(figsize = (18,10))
# ----> 2 ax.scatter(df['placement_score'], df['placement_offer'])
#       3 plt.show()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'placement_score'
